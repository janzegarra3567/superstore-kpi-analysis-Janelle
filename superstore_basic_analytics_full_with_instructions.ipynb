# %% [markdown]
# # 📘 Week 7 – OGL Individual Activity
# ## 🧮 Basic Business Analytics with Python (Excel Functions in Code + Graphs + Walkthroughs)
#
# **Goal:** Use Python to replicate Excel functions (`AVERAGE`, `SUMIF`, `COUNTIF`, `IF`, `IFS`) and visualize results. Then replicate these analyses in Excel, document your work, and submit via GitHub.

# %% [markdown]
# ### 📂 Files Needed (Download from Course Portal)
# - `superstore-basic-analytics-full-project.ipynb`
# - `Sample - Superstore.csv`
# - *(You will also create an Excel version)*

# %% [markdown]
# ### 🛠️ Step 1: Upload the Dataset
# Use this cell to upload the CSV file to Colab.

# %% [markdown]
# ### 📊 Step 2: Load the Data
# We use `pandas` to load the dataset, `numpy` for calculations, and `matplotlib.pyplot` to make graphs.

# %%
average_profit = df['Profit'].mean()
print('Average Profit Overall:', round(average_profit, 2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-97089909a416> in <cell line: 0>()
# ----> 1 average_profit = df['Profit'].mean()
#       2 print('Average Profit Overall:', round(average_profit, 2))
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# Cargar el archivo CSV
df = pd.read_csv('/content/sample_data/Sample - Superstore.csv', encoding='ISO-8859-1')

# Verificar que se cargó bien (ver primeras filas)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-55b06df9d033> in <cell line: 0>()
#       2
#       3 # Cargar el archivo CSV
# ----> 4 df = pd.read_csv('/content/sample_data/Sample - Superstore.csv', encoding='ISO-8859-1')
#       5
#       6 # Verificar que se cargó bien (ver primeras filas)
#
# ...

# %% [markdown]
# ### ✅ Task 1: AVERAGE – Average Profit Overall and by Region
# **Excel Equivalent:** `=AVERAGE()` and Pivot Table
#
# - First, we calculate the average of all values in the `Profit` column.
# - Then, we group data by `Region` and calculate average profit per region.

# %%
print('Average Profit:', df['Profit'].mean())
region_avg = df.groupby('Region')['Profit'].mean()
print(region_avg)
# Out:
# Average Profit: 28.65689630778467
# Region
# Central    17.092709
# East       32.135808
# South      28.857673
# West       33.849032
# Name: Profit, dtype: float64

# %% [markdown]
# ### ✅ Task 2: SUMIF – Total Sales in Region 'West'
# **Excel Equivalent:** `=SUMIF()`
#
# - We filter the DataFrame for rows where `Region` is `'West'`
# - Then, we calculate the sum of the `Sales` column for that subset.

# %%
west_sales = df[df['Region'] == 'West']['Sales'].sum()
print('Total Sales in West:', west_sales)
# Out:
# Total Sales in West: 725457.8245

# %% [markdown]
# ### ✅ Task 3: COUNTIF – Count Orders in 'Technology'
# **Excel Equivalent:** `=COUNTIF()`
#
# - We count the number of rows where the `Category` column is `'Technology'` using `.shape[0]`.

# %%
tech_orders = df[df['Category'] == 'Technology'].shape[0]
print('Technology Orders:', tech_orders)
# Out:
# Technology Orders: 1847

# %% [markdown]
# ### ✅ Task 4: IF – 'Performance' Based on Profit
# **Excel Equivalent:** `=IF(Profit > 0, 'High', 'Low')`
#
# - We use `np.where()` to assign `'High'` to rows with profit > 0 and `'Low'` otherwise.

# %%
df['Performance'] = np.where(df['Profit'] > 0, 'High', 'Low')
df[['Profit', 'Performance']].head()

# %%
df['Performance'].value_counts().plot(kind='bar', title='Order Performance Counts')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### ✅ Task 5: IFS – Profit Tier Classification
# **Excel Equivalent:** `=IFS()` or nested `=IF()`
#
# - We define ranges using `np.select()`:
#   - Profit < 0 → 'Loss'
#   - 0 ≤ Profit ≤ 500 → 'Low'
#   - 500 < Profit ≤ 2000 → 'Medium'
#   - Profit > 2000 → 'High'

# %%
conditions = [
    (df['Profit'] < 0),
    (df['Profit'] >= 0) & (df['Profit'] <= 500),
    (df['Profit'] > 500) & (df['Profit'] <= 2000),
    (df['Profit'] > 2000)
]
choices = ['Loss', 'Low', 'Medium', 'High']
df['Profit Tier'] = np.select(conditions, choices, default='Unknown')
df[['Profit', 'Profit Tier']].head()

# %%
df['Profit Tier'].value_counts().plot(kind='bar', title='Profit Tier Distribution')
plt.ylabel('Number of Orders')
plt.show()

# %% [markdown]
# ### ✅ Task 6: Total Sales per Category
# **Excel Equivalent:** Pivot Table with SUM on Sales by Category

# %%
category_sales = df.groupby('Category')['Sales'].sum()
print(category_sales)

# %%
category_sales.plot(kind='bar', title='Total Sales per Category')
plt.ylabel('Total Sales')
plt.show()

# %% [markdown]
# ### ✅ Task 7: Number of Orders by Ship Mode
# **Excel Equivalent:** Pivot Table COUNT on Ship Mode

# %%
shipmode_counts = df['Ship Mode'].value_counts()
print(shipmode_counts)

# %%
shipmode_counts.plot(kind='bar', title='Orders by Ship Mode')
plt.ylabel('Orders')
plt.show()

# %% [markdown]
# ### 🔁 Part 2: Do All Tasks in Excel Too
# Open `Sample - Superstore.csv` in Excel and replicate:
#
# - AVERAGE: `=AVERAGE()`
# - SUMIF, COUNTIF
# - IF for performance
# - IFS or nested IF for profit tier
# - Pivot Tables for sales and ship mode
#
# 📁 Save your Excel file as: `superstore-basic-analytics-yourname.xlsx`

# %% [markdown]
# ### 📁 GitHub Submission Instructions
# 1. Create repo: `week7-basic-analytics-yourname`
# 2. Upload:
# - `.ipynb` (this notebook)
# - `.xlsx` Excel file
# - `README.md`
# - (Optional) CSV dataset
# 3. Make repo **Public**
# 4. Submit GitHub link in course portal

# %% [markdown]
# ### 📝 README.md Template
#
# ```markdown
# # Week 7 – Basic Business Analytics Project
#
# **Student:** Your Name
# **Course:** CPSC 201 – Business Information Systems
#
# ## 🔍 Summary
# Replicated Excel functions in Python and visualized data using Pandas and Matplotlib.
#
# ## 📁 Files
# - .ipynb (Python version)
# - .xlsx (Excel version)
# - CSV (optional)
#
# ## 📊 Insights
# - West had highest sales
# - Standard Class was most used shipping
#
# ## 💡 Python vs Excel
# - Python is efficient for logic
# - Excel is visual but manual
#
# ## ✅ How to Use
# Run notebook top to bottom. Open Excel file to compare.
# ```

# %% [markdown]
# ### ✅ Submission Checklist
# - [ ] Notebook completed and saved
# - [ ] Excel file created
# - [ ] README.md written
# - [ ] GitHub repo public and submitted

# %% [markdown]
# # Task
# Tell me about this dataset.
#
# Here is all the data you need:
# "Sample - Superstore.csv"

# %% [markdown]
# ## Data loading
#
# ### Subtask:
# Load the data from "Sample - Superstore.csv" into a pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# Load the data from "Sample - Superstore.csv" into a pandas DataFrame and display the first few rows.

# %%
import pandas as pd

try:
    df = pd.read_csv('Sample - Superstore.csv')
    display(df.head())
except FileNotFoundError:
    print("Error: 'Sample - Superstore.csv' not found. Please ensure the file exists in the current directory.")
    df = None # Assign None to df in case of error
except Exception as e:
    print(f"An unexpected error occurred: {e}")
    df = None # Assign None to df in case of error
# Out:
# An unexpected error occurred: 'utf-8' codec can't decode byte 0xa0 in position 2944: invalid start byte

# %% [markdown]
# **Reasoning**:
# The previous attempt failed due to a decoding error.  I will try again, specifying the encoding as 'latin-1', which often resolves issues with files containing special characters.

# %%
import pandas as pd

try:
    df = pd.read_csv('Sample - Superstore.csv', encoding='latin-1')
    display(df.head())
except FileNotFoundError:
    print("Error: 'Sample - Superstore.csv' not found. Please ensure the file exists in the current directory.")
    df = None
except Exception as e:
    print(f"An unexpected error occurred: {e}")
    df = None
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ## Data exploration
#
# ### Subtask:
# Explore the loaded data to understand its structure.

# %% [markdown]
# **Reasoning**:
# Explore the data by checking its shape, data types, descriptive statistics, unique values in categorical columns, and missing values.

# %%
# Check the shape of the DataFrame
print("Shape of the DataFrame:", df.shape)

# Examine data types
print("\nData Types:\n", df.dtypes)

# Generate descriptive statistics for numerical columns
print("\nDescriptive Statistics:\n", df.describe())

# Identify unique values and frequencies for categorical columns
categorical_cols = df.select_dtypes(include=['object']).columns
for col in categorical_cols:
    print(f"\nUnique values and frequencies for '{col}':")
    print(df[col].value_counts())
    print("Number of unique values:", df[col].nunique())

# Check for missing values
print("\nMissing Values:\n", df.isnull().sum())
# Out:
# Shape of the DataFrame: (9994, 21)
#
# Data Types:
#  Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object
#
# Descriptive Statistics:
#              Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# ...

# %% [markdown]
# ## Data analysis
#
# ### Subtask:
# Calculate descriptive statistics and analyze the distribution of key variables.

# %% [markdown]
# **Reasoning**:
# Calculate descriptive statistics, analyze distributions, and investigate relationships between key variables.

# %%
# Calculate descriptive statistics for numerical columns
numerical_cols = ['Sales', 'Profit', 'Quantity', 'Discount']
print(df[numerical_cols].describe())

# Analyze the distribution of 'Sales', 'Profit', and 'Quantity'
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
plt.hist(df['Sales'], bins=30, color='skyblue', edgecolor='black')
plt.title('Distribution of Sales')

plt.subplot(1, 3, 2)
plt.hist(df['Profit'], bins=30, color='lightcoral', edgecolor='black')
plt.title('Distribution of Profit')

plt.subplot(1, 3, 3)
plt.hist(df['Quantity'], bins=30, color='lightgreen', edgecolor='black')
plt.title('Distribution of Quantity')
plt.tight_layout()
plt.show()


# Identify unique values and frequencies for categorical columns
categorical_cols = ['Category', 'Sub-Category', 'Ship Mode']
for col in categorical_cols:
    print(f"\nUnique values and frequencies for '{col}':")
    print(df[col].value_counts())

# Investigate the relationship between 'Sales', 'Profit', and 'Discount'
print("\nCorrelation between Sales, Profit, and Discount:")
print(df[['Sales', 'Profit', 'Discount']].corr())

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.scatter(df['Discount'], df['Sales'], color='purple', alpha=0.5)
plt.xlabel('Discount')
plt.ylabel('Sales')
plt.title('Discount vs. Sales')

plt.subplot(1, 2, 2)
plt.scatter(df['Discount'], df['Profit'], color='orange', alpha=0.5)
plt.xlabel('Discount')
plt.ylabel('Profit')
plt.title('Discount vs. Profit')
plt.tight_layout()
plt.show()
# Out:
#               Sales       Profit     Quantity     Discount
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001    28.656896     3.789574     0.156203
# std      623.245101   234.260108     2.225110     0.206452
# min        0.444000 -6599.978000     1.000000     0.000000
# 25%       17.280000     1.728750     2.000000     0.000000
# 50%       54.490000     8.666500     3.000000     0.200000
# 75%      209.940000    29.364000     5.000000     0.200000
# max    22638.480000  8399.976000    14.000000     0.800000
# Unique values and frequencies for 'Category':
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64
#
# Unique values and frequencies for 'Sub-Category':
# Sub-Category
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# ...

# %% [markdown]
# ## Data visualization
#
# ### Subtask:
# Visualize the distribution of key numerical and categorical variables.

# %% [markdown]
# **Reasoning**:
# Visualize the distribution of numerical and categorical variables using histograms, box plots, and bar charts. Also visualize the relationship between 'Sales', 'Profit', and 'Discount'.

# %%
import matplotlib.pyplot as plt

# Histograms for numerical variables
plt.figure(figsize=(16, 8))
plt.subplot(2, 2, 1)
plt.hist(df['Sales'], bins=30, color='skyblue', edgecolor='black')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.title('Distribution of Sales')

plt.subplot(2, 2, 2)
plt.hist(df['Profit'], bins=30, color='lightcoral', edgecolor='black')
plt.xlabel('Profit')
plt.ylabel('Frequency')
plt.title('Distribution of Profit')

plt.subplot(2, 2, 3)
plt.hist(df['Quantity'], bins=30, color='lightgreen', edgecolor='black')
plt.xlabel('Quantity')
plt.ylabel('Frequency')
plt.title('Distribution of Quantity')

plt.subplot(2, 2, 4)
plt.hist(df['Discount'], bins=30, color='gold', edgecolor='black')
plt.xlabel('Discount')
plt.ylabel('Frequency')
plt.title('Distribution of Discount')
plt.tight_layout()
plt.show()

# Box plots for numerical variables
plt.figure(figsize=(16, 8))
plt.subplot(2, 2, 1)
plt.boxplot(df['Sales'], vert=False, patch_artist=True, boxprops=dict(facecolor='skyblue'))
plt.xlabel('Sales')
plt.title('Box Plot of Sales')

plt.subplot(2, 2, 2)
plt.boxplot(df['Profit'], vert=False, patch_artist=True, boxprops=dict(facecolor='lightcoral'))
plt.xlabel('Profit')
plt.title('Box Plot of Profit')

plt.subplot(2, 2, 3)
plt.boxplot(df['Quantity'], vert=False, patch_artist=True, boxprops=dict(facecolor='lightgreen'))
plt.xlabel('Quantity')
plt.title('Box Plot of Quantity')

plt.subplot(2, 2, 4)
plt.boxplot(df['Discount'], vert=False, patch_artist=True, boxprops=dict(facecolor='gold'))
plt.xlabel('Discount')
plt.title('Box Plot of Discount')
plt.tight_layout()
plt.show()

# Bar charts for categorical variables
plt.figure(figsize=(16, 4))
for i, col in enumerate(['Category', 'Sub-Category', 'Ship Mode']):
    plt.subplot(1, 3, i+1)
    df[col].value_counts().plot(kind='bar', color=['skyblue', 'lightcoral', 'lightgreen', 'gold'])
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.title(f'Frequency of {col}')
    plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Relationship between Sales, Profit, and Discount
plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
plt.scatter(df['Discount'], df['Sales'], alpha=0.5)
plt.xlabel('Discount')
plt.ylabel('Sales')
plt.title('Discount vs. Sales')

plt.subplot(1, 2, 2)
plt.scatter(df['Discount'], df['Profit'], alpha=0.5, color='orange')
plt.xlabel('Discount')
plt.ylabel('Profit')
plt.title('Discount vs. Profit')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Summary:
#
# ### Q&A
# No questions were asked in the task.
#
# ### Data Analysis Key Findings
# * The dataset contains 9994 rows and 21 columns.
# * Key numerical variables like 'Sales' and 'Profit' exhibit right-skewed distributions and potential outliers.
# * 'Office Supplies' is the most frequent category, 'Binders' the most frequent sub-category, and 'Standard Class' the most frequent ship mode.
# * There's a weak negative correlation between 'Discount' and 'Profit', suggesting higher discounts might reduce profitability.
# * The 'Country' column only contains 'United States', limiting the scope of the analysis to a single country.
# * 'Order ID', 'Order Date', 'Ship Date', 'Customer ID', and 'Customer Name' columns have high cardinality.
# * The 'Order Date' and 'Ship Date' columns are of object type and should be converted to datetime objects.
#
# ### Insights or Next Steps
# * Investigate the outliers in 'Sales' and 'Profit' to understand their impact on the overall analysis.
# * Explore the relationship between 'Discount' and 'Profit' further, potentially segmenting the data by other variables to gain more nuanced insights.

# %% [markdown]
# # Task
# Tell me about this dataset.
#
# Here is all the data you need:
# "Sample - Superstore.csv"

# %% [markdown]
# ## Data loading
#
# ### Subtask:
# Load the data from "Sample - Superstore.csv" into a pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# Load the data from "Sample - Superstore.csv" into a pandas DataFrame and display the first 5 rows.

# %%
import pandas as pd

try:
    df = pd.read_csv('Sample - Superstore.csv')
    display(df.head())
except FileNotFoundError:
    print("Error: 'Sample - Superstore.csv' not found.")
    df = None
except pd.errors.ParserError:
    print("Error: Unable to parse the CSV file. Please check its format.")
    df = None
except Exception as e:
    print(f"An unexpected error occurred: {e}")
    df = None
# Out:
# An unexpected error occurred: 'utf-8' codec can't decode byte 0xa0 in position 2944: invalid start byte

# %% [markdown]
# **Reasoning**:
# The previous attempt failed due to a decoding error.  I'll try loading the file with a different encoding.  I'll try 'latin-1' encoding first, as it's a common alternative for CSV files that might have issues with UTF-8.

# %%
import pandas as pd

try:
    df = pd.read_csv('Sample - Superstore.csv', encoding='latin-1')
    display(df.head())
except FileNotFoundError:
    print("Error: 'Sample - Superstore.csv' not found.")
    df = None
except pd.errors.ParserError:
    print("Error: Unable to parse the CSV file. Please check its format.")
    df = None
except Exception as e:
    print(f"An unexpected error occurred: {e}")
    df = None
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ## Data exploration
#
# ### Subtask:
# Explore the loaded dataset to understand its structure, identify potential issues, and gain initial insights.

# %% [markdown]
# **Reasoning**:
# I need to explore the dataset's structure, identify potential issues, and gain initial insights by examining its shape, data types, descriptive statistics, missing values, unique values in categorical columns, and correlations between numerical features.  I will also visualize the distributions of key numerical variables.

# %%
# Check the shape of the DataFrame
print("Shape of the DataFrame:", df.shape)

# Examine data types
print("\nData Types:\n", df.dtypes)

# Descriptive statistics for numerical columns
print("\nDescriptive Statistics:\n", df.describe())

# Identify missing values
print("\nMissing Values per column:\n", df.isnull().sum())

# Explore unique values in categorical columns
categorical_cols = df.select_dtypes(include=['object']).columns
for col in categorical_cols:
    print(f"\nUnique values in '{col}':\n{df[col].unique()[:20]}") # Limiting to 20 for brevity

# Calculate the correlation matrix for numerical features
numerical_cols = df.select_dtypes(include=['number']).columns
correlation_matrix = df[numerical_cols].corr()
print("\nCorrelation Matrix:\n", correlation_matrix)

# Visualize distributions of key numerical variables
import matplotlib.pyplot as plt

plt.figure(figsize=(16, 10))

plt.subplot(2, 2, 1)
plt.hist(df['Sales'], bins=30, color='skyblue', edgecolor='black')
plt.title('Distribution of Sales')

plt.subplot(2, 2, 2)
plt.hist(df['Profit'], bins=30, color='lightcoral', edgecolor='black')
plt.title('Distribution of Profit')

plt.subplot(2, 2, 3)
plt.hist(df['Quantity'], bins=30, color='lightgreen', edgecolor='black')
plt.title('Distribution of Quantity')

plt.subplot(2, 2, 4)
plt.hist(df['Discount'], bins=30, color='gold', edgecolor='black')
plt.title('Distribution of Discount')

plt.tight_layout()
plt.show()
# Out:
# Shape of the DataFrame: (9994, 21)
#
# Data Types:
#  Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object
#
# Descriptive Statistics:
#              Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# ...

# %% [markdown]
# ## Data analysis
#
# ### Subtask:
# Analyze key variables (Sales, Profit, Quantity, Discount) to understand their distributions and relationships. Calculate key statistics and explore potential correlations.

# %% [markdown]
# **Reasoning**:
# Calculate key statistics for 'Sales', 'Profit', 'Quantity', and 'Discount', and explore their relationships using correlation and scatter plots.

# %%
# Calculate key statistics
key_stats = df[['Sales', 'Profit', 'Quantity', 'Discount']].describe()
print("Key statistics:\n", key_stats)

# Calculate correlation coefficients
correlation_matrix = df[['Sales', 'Profit', 'Quantity', 'Discount']].corr()
print("\nCorrelation Matrix:\n", correlation_matrix)

# Visualize relationships using scatter plots
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 10))

plt.subplot(2, 2, 1)
plt.scatter(df['Quantity'], df['Sales'], alpha=0.5)
plt.xlabel('Quantity')
plt.ylabel('Sales')
plt.title('Sales vs. Quantity')

plt.subplot(2, 2, 2)
plt.scatter(df['Discount'], df['Profit'], alpha=0.5, color='orange')
plt.xlabel('Discount')
plt.ylabel('Profit')
plt.title('Profit vs. Discount')

plt.subplot(2, 2, 3)
plt.scatter(df['Discount'], df['Sales'], alpha=0.5, color='green')
plt.xlabel('Discount')
plt.ylabel('Sales')
plt.title('Sales vs. Discount')

plt.subplot(2, 2, 4)
plt.scatter(df['Quantity'], df['Profit'], alpha=0.5, color='red')
plt.xlabel('Quantity')
plt.ylabel('Profit')
plt.title('Profit vs. Quantity')

plt.tight_layout()
plt.show()
# Out:
# Key statistics:
#                Sales       Profit     Quantity     Discount
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001    28.656896     3.789574     0.156203
# std      623.245101   234.260108     2.225110     0.206452
# min        0.444000 -6599.978000     1.000000     0.000000
# 25%       17.280000     1.728750     2.000000     0.000000
# 50%       54.490000     8.666500     3.000000     0.200000
# 75%      209.940000    29.364000     5.000000     0.200000
# max    22638.480000  8399.976000    14.000000     0.800000
#
# Correlation Matrix:
#               Sales    Profit  Quantity  Discount
# Sales     1.000000  0.479064  0.200795 -0.028190
# Profit    0.479064  1.000000  0.066253 -0.219487
# Quantity  0.200795  0.066253  1.000000  0.008623
# Discount -0.028190 -0.219487  0.008623  1.000000

# %% [markdown]
# **Reasoning**:
# Investigate the relationship between 'Discount' and 'Profit' by segmenting the data and analyzing profit within discount levels.  Then, analyze sales and profit by 'Category' and 'Sub-Category'.

# %%
# Investigate the relationship between Discount and Profit
import matplotlib.pyplot as plt

# Segment data by discount levels and analyze profit
discount_segments = pd.cut(df['Discount'], bins=[0, 0.2, 0.4, 0.6, 0.8, 1], labels=['0-0.2', '0.2-0.4', '0.4-0.6', '0.6-0.8', '0.8-1'])
profit_by_discount = df.groupby(discount_segments)['Profit'].mean()
print("\nAverage profit by discount segment:\n", profit_by_discount)

plt.figure(figsize=(8, 6))
profit_by_discount.plot(kind='bar', color='skyblue')
plt.xlabel('Discount Level')
plt.ylabel('Average Profit')
plt.title('Average Profit by Discount Segment')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Analyze sales and profit by Category and Sub-Category
sales_by_category = df.groupby('Category')['Sales'].mean()
profit_by_category = df.groupby('Category')['Profit'].mean()
sales_by_subcategory = df.groupby('Sub-Category')['Sales'].mean()
profit_by_subcategory = df.groupby('Sub-Category')['Profit'].mean()

print("\nAverage sales by category:\n", sales_by_category)
print("\nAverage profit by category:\n", profit_by_category)
print("\nAverage sales by sub-category:\n", sales_by_subcategory)
print("\nAverage profit by sub-category:\n", profit_by_subcategory)

plt.figure(figsize=(16, 6))

plt.subplot(1, 2, 1)
sales_by_category.plot(kind='bar', color=['skyblue', 'lightcoral', 'lightgreen'])
plt.title('Average Sales by Category')

plt.subplot(1, 2, 2)
profit_by_category.plot(kind='bar', color=['skyblue', 'lightcoral', 'lightgreen'])
plt.title('Average Profit by Category')

plt.tight_layout()
plt.show()

plt.figure(figsize=(16, 8))
sales_by_subcategory.plot(kind='bar', color='skyblue')
plt.title('Average Sales by Sub-Category')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
plt.figure(figsize=(16, 8))
profit_by_subcategory.plot(kind='bar', color='lightcoral')
plt.title('Average Profit by Sub-Category')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-5-59b4d01c754f>:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   profit_by_discount = df.groupby(discount_segments)['Profit'].mean()
# Average profit by discount segment:
#  Discount
# 0-0.2       26.501571
# 0.2-0.4    -77.864055
# 0.4-0.6   -134.624160
# 0.6-0.8    -98.348741
# 0.8-1             NaN
# Name: Profit, dtype: float64
# Average sales by category:
#  Category
# Furniture          349.834887
# Office Supplies    119.324101
# Technology         452.709276
# Name: Sales, dtype: float64
#
# Average profit by category:
#  Category
# Furniture           8.699327
# Office Supplies    20.327050
# Technology         78.752002
# Name: Profit, dtype: float64
#
# Average sales by sub-category:
#  Sub-Category
# Accessories     215.974604
# Appliances      230.755710
# ...

# %% [markdown]
# ## Data visualization
#
# ### Subtask:
# Visualize the distributions of key variables and their relationships to gain insights.

# %% [markdown]
# **Reasoning**:
# Create histograms and box plots for 'Sales', 'Profit', 'Quantity', and 'Discount', and then create scatter plots to visualize relationships between key variables.

# %%
import matplotlib.pyplot as plt

# Histograms
plt.figure(figsize=(16, 8))
plt.subplot(2, 2, 1)
plt.hist(df['Sales'], bins=30, color='skyblue', edgecolor='black')
plt.title('Distribution of Sales')
plt.subplot(2, 2, 2)
plt.hist(df['Profit'], bins=30, color='lightcoral', edgecolor='black')
plt.title('Distribution of Profit')
plt.subplot(2, 2, 3)
plt.hist(df['Quantity'], bins=30, color='lightgreen', edgecolor='black')
plt.title('Distribution of Quantity')
plt.subplot(2, 2, 4)
plt.hist(df['Discount'], bins=30, color='gold', edgecolor='black')
plt.title('Distribution of Discount')
plt.tight_layout()
plt.show()

# Box plots
plt.figure(figsize=(16, 8))
plt.subplot(2, 2, 1)
plt.boxplot(df['Sales'], vert=False, patch_artist=True, boxprops=dict(facecolor='skyblue'))
plt.title('Sales')
plt.subplot(2, 2, 2)
plt.boxplot(df['Profit'], vert=False, patch_artist=True, boxprops=dict(facecolor='lightcoral'))
plt.title('Profit')
plt.subplot(2, 2, 3)
plt.boxplot(df['Quantity'], vert=False, patch_artist=True, boxprops=dict(facecolor='lightgreen'))
plt.title('Quantity')
plt.subplot(2, 2, 4)
plt.boxplot(df['Discount'], vert=False, patch_artist=True, boxprops=dict(facecolor='gold'))
plt.title('Discount')
plt.tight_layout()
plt.show()

# Scatter plots
plt.figure(figsize=(16, 12))

plt.subplot(2, 2, 1)
plt.scatter(df['Sales'], df['Profit'], alpha=0.5)
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.title('Sales vs. Profit')

plt.subplot(2, 2, 2)
plt.scatter(df['Discount'], df['Profit'], alpha=0.5, color='orange')
plt.xlabel('Discount')
plt.ylabel('Profit')
plt.title('Discount vs. Profit')

plt.subplot(2, 2, 3)
plt.scatter(df['Quantity'], df['Sales'], alpha=0.5, color='green')
plt.xlabel('Quantity')
plt.ylabel('Sales')
plt.title('Quantity vs. Sales')

plt.subplot(2, 2, 4)
plt.scatter(df['Discount'], df['Sales'], alpha=0.5, color='red')
plt.xlabel('Discount')
plt.ylabel('Sales')
plt.title('Discount vs. Sales')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Reasoning**:
# Visualize top-performing categories and sub-categories based on sales and profit using bar charts.

# %%
import matplotlib.pyplot as plt

# Calculate sales and profit by category
sales_by_category = df.groupby('Category')['Sales'].sum()
profit_by_category = df.groupby('Category')['Profit'].sum()

# Plot sales by category
plt.figure(figsize=(8, 6))
sales_by_category.plot(kind='bar', color=['skyblue', 'lightcoral', 'lightgreen'])
plt.title('Total Sales by Category')
plt.xlabel('Category')
plt.ylabel('Total Sales')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# Plot profit by category
plt.figure(figsize=(8, 6))
profit_by_category.plot(kind='bar', color=['skyblue', 'lightcoral', 'lightgreen'])
plt.title('Total Profit by Category')
plt.xlabel('Category')
plt.ylabel('Total Profit')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()


# Calculate sales and profit by sub-category
sales_by_subcategory = df.groupby('Sub-Category')['Sales'].sum()
profit_by_subcategory = df.groupby('Sub-Category')['Profit'].sum()

# Plot sales by sub-category
plt.figure(figsize=(12, 6))
sales_by_subcategory.sort_values(ascending=False).plot(kind='bar', color='skyblue')
plt.title('Total Sales by Sub-Category')
plt.xlabel('Sub-Category')
plt.ylabel('Total Sales')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()


# Plot profit by sub-category
plt.figure(figsize=(12, 6))
profit_by_subcategory.sort_values(ascending=False).plot(kind='bar', color='lightcoral')
plt.title('Total Profit by Sub-Category')
plt.xlabel('Sub-Category')
plt.ylabel('Total Profit')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The dataset contains 9994 rows and 21 columns.
# *   There are no missing values in the dataset.
# *   The `Country` column has only one unique value ("United States").
# *   `Sales` and `Profit` distributions are skewed with long tails and contain potential outliers.
# *   `Profit` shows a wide range, including significantly negative values.
# *   There is a moderate positive correlation between `Sales` and `Profit` (0.48).
# *   There is a moderate negative correlation between `Discount` and `Profit` (-0.22).
# *   Average profit decreases as discount levels increase; discount levels above 0.2 generally result in negative average profit.
# *   Technology is the most profitable category, while Tables and Bookcases are sub-categories with negative average profit.
#
# ### Insights or Next Steps
#
# *   Investigate the transactions with high discounts and negative profits to understand the reasons behind the losses.
# *   Consider removing the 'Country' column as it has only one unique value and won't contribute to differentiating data points within the United States.
